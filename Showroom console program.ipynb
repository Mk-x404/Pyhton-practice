# %%
# SHOWROOM CONSOLE
print ("1. Toyota ")
print ("2. Honda ")
print ("3. Changan")
print ("4. Kia")
print ("5. Hyundai")
menu = int(input (" These are the available companies, choose a company : "))

    #TOYOTA - INDEX 0
car = [
[
    ["Corolla","Grande", 2018 , "3.5 Million"],
       ["Vitz","Hybrid f 1.5",2015, "4.3 Million"],
       ["Axio","Hybrid G", 2017, "3.2 Million"],
       ["Revo","2.8 G Automatic", 2019, "6.5 Million"],
       ["Mark X", "250G F Package", 2016, "5.0 Million"]],
[   #HONDA - INDEX 1
    ["Civic", "Oriel 1.8 i-VTEC", 2018, "4.0 Million"],
       ["BRV", "i-VTEC S", 2019, "3.8 Million"],
       ["City", "1.3 i-VTEC", 2017, "3.1 Million"],
       ["Grace", "Hybrid LX", 2015, "3.5 Million"],
       ["Accord", "2.4 VTi-L", 2020, "6.2 Million"]],
[   #CHANGAN - INDEX 2
    ["Alsvin", "1.5 DCT Lumiere", 2018, "3.3 Million"],
        ["Karvaan", "Plus", 2019, "2.4 Million"],
        ["Oshan X7", "FutureSense", 2021, "5.8 Million"],
        ["Changan M9", "Base Pickup", 2020, "2.9 Million"],
        ["Changan Uni-T", "Sport", 2021, "6.5 Million"]],
[   #KIA - INDEX 3
    ["Sportage", "AWD", 2019, "7.0 Million"],
        ["Stonic", "EX+", 2020, "4.5 Million"],
        ["Picanto", "AT", 2018, "2.8 Million"],
        ["Carnival", "GLS+ 3.5", 2021, "9.5 Million"],
        ["Sorento", "2.4 FWD", 2020, "7.8 Million"]],
[   #HYUNDAI - INDEX 4
    ["Sonata", "2.5 Smart", 2019, "7.3 Million"],
        ["Elantra", "2.0 GLS", 2020, "5.3 Million"],
        ["Tucson", "AWD A/T Ultimate", 2021, "6.8 Million"],
        ["Ioniq 5", "Long Range AWD", 2022, "10 Million"],
        ["Santro", "Club GV", 2017, "2.0 Million"]],
]
if menu == 1:
    print (f"Showing results from selected company: 1. {car[0][0][0]}")
    print (f"2. {car[0][1][0]}")
    print (f"3. {car[0][2][0]}")
    print (f"4. {car[0][3][0]}")
    print (f"5. {car[0][4][0]}")
elif menu == 2:
    print (f"Showing results from selected company: {car[1][0][0]}")
    print (f"2. {car[1][0][0]}")
    print (f"3. {car[1][1][0]}")
    print (f"4. {car[1][2][0]}")
    print (f"5. {car[1][3][0]}")
elif menu == 3:
    print (f"Showing results from selected company: {car[2][0][0]}")
    print (f"2. {car[2][1][0]}")
    print (f"3. {car[2][2][0]}")
    print (f"4. {car[2][3][0]}")
    print (f"5. {car[2][4][0]}")
elif menu == 4 :
    print (f"Showing results from selected company: {car[3][0][0]}")
    print (f"2. {car[3][1][0]}")
    print (f"3. {car[3][2][0]}")
    print (f"4. {car[3][3][0]}")
    print (f"5. {car[3][4][0]}")
elif menu == 5 :
    print (f"Showing results from selected company: {car[4][0][0]}")
    print (f"2. {car[4][1][0]}")
    print (f"3. {car[4][2][0]}")
    print (f"4. {car[4][3][0]}")
    print (f"5. {car[4][4][0]}")

else :
    print("Invalid choice, Sorry !!")
# Out:
# 1. Toyota
# 2. Honda
# 3. Changan
# 4. Kia
# 5. Hyundai
# Showing results from selected company: 1. Corolla
# 2. Vitz
# 3. Axio
# 4. Revo
# 5. Mark X
